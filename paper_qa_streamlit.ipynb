# %% [markdown]
# # Run streamlit QA app from a Google Colab Notebook
# > Created by [Shoeb Shaikh](https://www.linkedin.com/in/shoeb786)

# %% [markdown]
# You can run this notebook on GPU for relatively faster processsing. Bear in mind, that a GPU might not be always available. This code can still run on CPU.
#
# - Go to **Edit**
#
# ![image.png](data:image/png;base64,...)
#
# - Click on **Notebook settings**, and select **GPU**
#
# ![image.png](data:image/png;base64,...)

# %%
# !git clone https://github.com/shoebNTU/paper-qa.git
# Out:
# Cloning into 'paper-qa'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 92 (delta 54), reused 24 (delta 13), pack-reused 0
# Unpacking objects: 100% (92/92), 41.01 KiB | 1.11 MiB/s, done.

# %%
# %cd paper-qa
# Out:
# /content/paper-qa

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.7/960.7 kB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 27.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 98.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 105.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 56.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.3/249.3 kB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 87.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Install localtunnel

# %%
# !npm install localtunnel
# Out:
# npm WARN saveError ENOENT: no such file or directory, open '/content/paper-qa/package.json'
# npm notice created a lockfile as package-lock.json. You should commit this file.
# npm WARN enoent ENOENT: no such file or directory, open '/content/paper-qa/package.json'
# npm WARN paper-qa No description
# npm WARN paper-qa No repository field.
# npm WARN paper-qa No README data
# npm WARN paper-qa No license field.
#
# + localtunnel@2.0.2
# added 22 packages from 22 contributors and audited 22 packages in 2.199s
#
# 3 packages are looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities

# %% [markdown]
# ## Run streamlit in background

# %%
# !streamlit run qa.py &>/content/logs.txt &

# %% [markdown]
# ## Expose the port 8501
# Click the shown `url`, and enter the `ip-address` when prompted to do so

# %%
# !npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 34.172.251.243
# npx: installed 22 in 2.031s
# your url is: https://good-cobras-smash.loca.lt
